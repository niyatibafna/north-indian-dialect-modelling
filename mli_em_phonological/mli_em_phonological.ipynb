# %%
import sys
sys.path.append("../evaluation_languages_home/eval_scripts/")
from eval import Evaluation

# %%
#!/usr/bin/env python3

import os
import argparse
import math
import json
from collections import defaultdict, Counter
import pandas as pd
import editdistance
import Levenshtein as lv

class MLI_EM_PHONOLOGICAL:

    # def __init__(self, source_lang, target_lang):
    #     '''Initialize langs'''
    #     self.source_lang = source_lang
    #     self.target_lang = target_lang


    def get_args(self):
        parser = argparse.ArgumentParser(description = "Build a lexicon from 2 corpora using NED.")
        parser.add_argument("--source_file", type=str, default=None, required=True, help="Source corpus filepath")
        parser.add_argument("--target_file", type=str, default=None, required=True, help="Target corpus filepath")
        parser.add_argument("--max_lexicon_length", type=int, default=math.inf, help="Maximum length of extracted lexicon")
        parser.add_argument("--min_source_freq", type=int, default=2, help="Min freq of source side words")
        parser.add_argument("--min_target_freq", type=int, default=2, help="Min freq of target side words")
        parser.add_argument("--OUTPATH", type=str, help="Path for saving lexicon (JSON)")

        return parser.parse_args()

    def read_file(self, filepath):
        '''Reads text file and returns as string'''
        with open(filepath, "r") as f:
            return f.read()

    def get_lexicon_words(self, source_words, target_words, max_lexicon_length, min_source_freq, min_target_freq):
        '''Decide which source-side words will be in the lexicon'''

        cand_source_words = defaultdict(lambda:0, {w:f for w, f in source_words.most_common(max_lexicon_length) if f >= min_source_freq})
        cand_target_words = defaultdict(lambda:0, {w:f for w, f in target_words.items() if f >= min_target_freq})

        return cand_source_words, cand_target_words

    def ned_match(self, word, cand_target_words):
        '''Find best match using NED'''
        vowel_range = list(range(2305, 2315)) + list(range(2317, 2325)) + list(range(2365, 2384))
        bad_char_range = range(2364, 2367)

        min_dist, best_word = 2, ""
        for cand in cand_target_words:
            if cand[0] != word[0]:
                continue
            # cons_sequence_1 = "".join([c for c in word if ord(c) not in bad_char_range])
            # cons_sequence_2 = "".join([c for c in cand if ord(c) not in bad_char_range])
            # if cons_sequence_1 != cons_sequence_2:
            #     continue

            ned = editdistance.eval(word, cand)/max(len(word), len(cand))
            if ned < min_dist:
                min_dist = ned
                best_word = cand

        return best_word, min_dist

    
    def build_ops(self, word, cand_target_words, ops_freq = None, best_candidates = None):
        '''Find minimal Levenshtein operations'''

        vowel_range = list(range(2305, 2315)) + list(range(2317, 2325)) + list(range(2365, 2384))
        bad_char_range = range(2364, 2367)

        for cand in cand_target_words:

            ops = lv.editops(word, cand)
            if len(ops) == 1:
    #             print(word, cand, "\n")
                for op in ops:
                    if op[0] == "replace":
                        char1 = word[op[1]]
                        char2 = cand[op[2]]
                        ops_freq[char1][char2] += 1
                        best_candidates[word].add(cand)


        return ops_freq, best_candidates
    
    def find_new_equivalents(self, sound_changes, best_candidates):
        '''Finds new equivalents given sound changes'''
        new_eqs = defaultdict(lambda: dict())
        for source in best_candidates:
            for cand in best_candidates[source]:
                ops = lv.editops(source, cand)
                if len(ops) == 1 and ops[0][0]=="replace":
                    char1 = source[ops[0][1]]
                    char2 = cand[ops[0][2]]
                    if char2 in accepted_changes[char1]:
                        new_eqs[source][cand] = "NA"

        return new_eqs

    def build_lexicon(self, cand_source_words, cand_target_words, source_words, target_words):
        '''Build bilingual lexicon using NED'''
        lexicon = defaultdict(lambda: dict())

        for word in cand_source_words:
            best_word, ned = self.ned_match(word, cand_target_words)
            lexicon[word][best_word] = 1 - ned

        return lexicon

    def save_lexicon(self, lexicon, OUTPATH):
        '''Dump lexicon'''
        OUTDIR = "/".join(OUTPATH.split("/")[:-1])+"/"
        if not os.path.isdir(OUTDIR):
            os.makedirs(OUTDIR)

        with open(OUTPATH, "w") as f:
            json.dump(lexicon, f, ensure_ascii = False, indent = 2)


    def driver(self, source_file, target_file, max_lexicon_length = math.inf, min_source_freq = 2, min_target_freq = 2, OUTPATH = None):

        # Read files
        source_corpus = self.read_file(source_file)
        target_corpus = self.read_file(target_file)

        # Filter
        source_words = Counter(source_corpus.split())
        target_words = Counter(target_corpus.split())
        
        return source_words, target_words

        max_lexicon_length = min(max_lexicon_length, len(source_words))
        cand_source_words, cand_target_words = self.get_lexicon_words(source_words, target_words, max_lexicon_length, min_source_freq, min_target_freq)

        # Build lexicon
        lexicon = self.build_lexicon(cand_source_words, cand_target_words, source_words, target_words)

        # Save lexicon
        if OUTPATH:
            self.save_lexicon(lexicon, OUTPATH)

    def main(self):
        args = self.get_args()
        self.driver(args.source_file, args.target_file, \
        args.max_lexicon_length, args.min_source_freq, args.min_target_freq, \
        args.OUTPATH)

# %%
# Import file paths

DATADIR="../data/crawled_cleaned/"
anchor="hindi-urdu"
source_file=DATADIR+anchor+".txt"
target="bhojpuri"
target_file=DATADIR+target+".txt"
gold_file = "../evaluation_languages_home/eval_data/lexicons/hindi-urdu_source/hindi-urdu_bhojpuri.json"

# %%
# Object of above class, get source and target words

obj = MLI_EM_PHONOLOGICAL()
source_words, target_words = obj.driver(source_file, target_file)

print(len(source_words), len(target_words))

# %%
# Build ops_freq by calling build_ops on every source word.

ops_freq = defaultdict(lambda: defaultdict(lambda: 0))
best_candidates = defaultdict(lambda: set())

for source in list(source_words.keys())[:2000]:
    ops_freq, best_candidates = obj.build_ops(source, target_words, ops_freq, best_candidates)

# %%
# Find accepted changes by picking the cream of ops_freq

N = 10

all_changes = {(char, target): ops_freq[char][target] for char in ops_freq for target in ops_freq[char]}

best_changes = sorted(all_changes.items(), key = lambda x: x[1], reverse = True)[:N]

accepted_changes = defaultdict(lambda: set())
for (char, target), freq in best_changes:
    accepted_changes[char].add(target)

# %%
accepted_changes
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'े': {'ा', 'ी'},
#              'ा': {'ि', 'ी', 'े', 'ो'},
#              'ी': {'ा', 'े'},
#              'न': {'त'},
#              'त': {'न'}})

# %%
# Find new equivalents based on accepted_changes

new_eqs = obj.find_new_equivalents(accepted_changes, best_candidates)

# %%
type(new_eqs)
# Out:
# collections.defaultdict

# %%
# Evaluate new_eqs against gold lexicon
obj_eval = Evaluation()
gold_lexicon = obj_eval.read_files(gold_file)
result = obj_eval.eval(gold_lexicon, new_eqs, type = "loose")

# %%
result
# Out:
# {'accuracy': 0.0, 'found': 41, 'total': 139}

# %%
new_eqs
# Out:
# defaultdict(<function __main__.MLI_EM_PHONOLOGICAL.find_new_equivalents.<locals>.<lambda>()>,
#             {'मोरा': {'मोरि': 'NA', 'मोरे': 'NA', 'मोरी': 'NA'},
#              'अभागा': {'अभागि': 'NA', 'अभागी': 'NA', 'अभागे': 'NA'},
#              'न': {'त': 'NA'},
#              'जागा': {'जागो': 'NA',
#               'जागे': 'NA',
#               'जोगा': 'NA',
#               'जागी': 'NA',
#               'जागि': 'NA'},
#              'ले': {'ली': 'NA', 'ला': 'NA'},
#              'भागा': {'भागी': 'NA', 'भागि': 'NA', 'भागे': 'NA'},
#              'हाय': {'होय': 'NA', 'हिय': 'NA'},
#              'ना': {'नी': 'NA', 'ने': 'NA', 'ता': 'NA'},
#              'मोरी': {'मोरा': 'NA', 'मोरे': 'NA'},
#              'पे': {'पा': 'NA', 'पी': 'NA'},
#              'बैठा': {'बैठो': 'NA', 'बैठे': 'NA', 'बैठी': 'NA', 'बैठि': 'NA'},
#              'मोरे': {'मोरा': 'NA', 'मोरी': 'NA'},
#              'माथे': {'माथा': 'NA'},
#              'का': {'को': 'NA', 'की': 'NA', 'कि': 'NA', 'के': 'NA'},
#              'नथुनी': {'नथुना': 'NA'},
#              'राम': {'रोम': 'NA'},
#              'सुन': {'सुत': 'NA'},
#              'सखी': {'सखा': 'NA'},
#              'पापी': {'पापे': 'NA', 'पापा': 'NA'},
#              'की': {'के': 'NA', 'का': 'NA'},
#              'लगता': {'लगती': 'NA', 'लगते': 'NA'},
#              'छोटी': {'छोटा': 'NA', 'छोटे': 'NA'},
#              'सी': {'से': 'NA', 'सा': 'NA'},
#              'तीली': {'नीली': 'NA', 'ताली': 'NA', 'तेली': 'NA'},
#              'से': {'सी': 'NA', 'सा': 'NA'},
#              'भी': {'भे': 'NA', 'भा': 'NA'},
#              'दे': {'दी': 'NA', 'दा': 'NA'},
#              'सकती': {'सकते': 'NA', 'सकता': 'NA'},
#              'किसी': {'किसे': 'NA'},
#              'हमारा': {'हमारे': 'NA', 'हमारी': 'NA'},
#              'हमारी': {'हमारा': 'NA', 'हमारे': 'NA'},
#              'में': {'मां': 'NA'},
#              'रहेंगी': {'रहेंगे': 'NA'},
#              'ही': {'हा': 'NA', 'हे': 'NA'},
#              'छोटे': {'छोटी': 'NA', 'छोटा': 'NA'},
#              'भरे': {'भरा': 'NA', 'भरी': 'NA'},
#              'होते': {'होता': 'NA', 'होती': 'NA', 'होने': 'NA'},
#              'बदलें': {'बदलीं': 'NA'},
#              'वे': {'वी': 'NA', 'वा': 'NA'},
#              'करे': {'करा': 'NA', 'करी': 'NA'},
#              'भले': {'भली': 'NA', 'भला': 'NA'},
#              'हमारे': {'हमारा': 'NA', 'हमारी': 'NA'},
#              'बात': {'बान': 'NA', 'बित': 'NA', 'बीत': 'NA'},
#              'जैसा': {'जैसी': 'NA', 'जैसे': 'NA'},
#              'नकचढ़ा': {'नकचढ़े': 'NA'},
#              'फैले': {'फैली': 'NA', 'फैला': 'NA'},
#              'बिखरे': {'बिखरी': 'NA'},
#              'करते': {'करती': 'NA', 'करता': 'NA', 'करने': 'NA'},
#              'ठीक': {'ठाक': 'NA', 'ठेक': 'NA'},
#              'निकालें': {'निकालीं': 'NA'},
#              'राह': {'रेह': 'NA'},
#              'रहे': {'रहा': 'NA', 'रही': 'NA'},
#              'जाती': {'जिती': 'NA',
#               'जोती': 'NA',
#               'जाते': 'NA',
#               'जीती': 'NA',
#               'जाता': 'NA',
#               'जानी': 'NA'},
#              'अपने': {'अपनी': 'NA', 'अपना': 'NA'},
#              'रचना': {'रचने': 'NA', 'रचता': 'NA'},
#              'दीख': {'देख': 'NA'},
#              'लगे': {'लगा': 'NA', 'लगी': 'NA'},
#              'चलने': {'चलते': 'NA', 'चलनी': 'NA', 'चलना': 'NA'},
#              'वाले': {'वाला': 'NA', 'वाली': 'NA'},
#              'अपनी': {'अपना': 'NA', 'अपने': 'NA'},
#              'इसी': {'इसा': 'NA', 'इसे': 'NA'},
#              'टूटे': {'टूटी': 'NA', 'टूटा': 'NA'},
#              'रहता': {'रहना': 'NA', 'रहती': 'NA', 'रहते': 'NA'},
#              'पास': {'पिस': 'NA', 'पोस': 'NA'},
#              'उसका': {'उसके': 'NA', 'उसकी': 'NA', 'उसको': 'NA'},
#              'या': {'ये': 'NA'},
#              'चली': {'चले': 'NA', 'चला': 'NA'},
#              'रही': {'रहा': 'NA', 'रहे': 'NA'},
#              'होती': {'होता': 'NA', 'होनी': 'NA', 'होते': 'NA'},
#              'कितना': {'कितनी': 'NA', 'कितने': 'NA'},
#              'अकेला': {'अकेले': 'NA', 'अकेली': 'NA'},
#              'देता': {'देती': 'NA',
#               'देते': 'NA',
#               'देति': 'NA',
#               'देना': 'NA',
#               'दाता': 'NA'},
#              'उसके': {'उसकी': 'NA', 'उसका': 'NA'},
#              'चलत': {'चलन': 'NA'},
#              'तन': {'तत': 'NA'},
#              'गन': {'गत': 'NA'},
#              'मादक': {'मोदक': 'NA'},
#              'सत': {'सन': 'NA'},
#              'आगे': {'आगा': 'NA', 'आगी': 'NA'},
#              'भला': {'भले': 'NA', 'भलो': 'NA', 'भली': 'NA'},
#              'जाना': {'जाता': 'NA',
#               'जीना': 'NA',
#               'जानी': 'NA',
#               'जाने': 'NA',
#               'जानो': 'NA',
#               'जानि': 'NA'},
#              'कहाँ': {'कहोँ': 'NA'},
#              'ने': {'ते': 'NA', 'ना': 'NA', 'नी': 'NA'},
#              'रक्खा': {'रक्खी': 'NA'},
#              'बनाया': {'बताया': 'NA', 'बनिया': 'NA'},
#              'था': {'थे': 'NA', 'थी': 'NA'},
#              'थी': {'थे': 'NA', 'था': 'NA'},
#              'जाने': {'जाते': 'NA',
#               'जीने': 'NA',
#               'जेने': 'NA',
#               'जानी': 'NA',
#               'जाना': 'NA'},
#              'लिया': {'लियो': 'NA', 'लिये': 'NA'},
#              'ये': {'या': 'NA'},
#              'निकाली': {'निकाले': 'NA', 'निकाला': 'NA'},
#              'टूटने': {'टूटते': 'NA'},
#              'खुली': {'खुले': 'NA', 'खुला': 'NA'},
#              'धरा': {'धरि': 'NA', 'धरे': 'NA', 'धरी': 'NA'},
#              'बार': {'बेर': 'NA', 'बोर': 'NA', 'बीर': 'NA'},
#              'क्या': {'क्यो': 'NA'},
#              'मिले': {'मिली': 'NA', 'मिला': 'NA'},
#              'माँगते': {'माँगने': 'NA', 'माँगता': 'NA'},
#              'मौत': {'मौन': 'NA'},
#              'के': {'की': 'NA', 'का': 'NA'},
#              'पीता': {'पीते': 'NA', 'पीना': 'NA', 'पीती': 'NA', 'पाता': 'NA'},
#              'रहा': {'रहि': 'NA', 'रहो': 'NA', 'रही': 'NA', 'रहे': 'NA'},
#              'बदन': {'बदत': 'NA'},
#              'कहीं': {'कहें': 'NA', 'कहां': 'NA'},
#              'बदलने': {'बदलना': 'NA', 'बदलते': 'NA'},
#              'पेश': {'पाश': 'NA'},
#              'जानते': {'जानने': 'NA', 'जानता': 'NA', 'जानती': 'NA'},
#              'सकते': {'सकती': 'NA', 'सकने': 'NA', 'सकता': 'NA'},
#              'तेरी': {'तेरा': 'NA', 'तेरे': 'NA', 'तारी': 'NA'},
#              'भरती': {'भरता': 'NA', 'भरते': 'NA'},
#              'मेरे': {'मारे': 'NA', 'मेरी': 'NA', 'मेरा': 'NA'},
#              'मन': {'मत': 'NA'},
#              'झांकते': {'झांकती': 'NA', 'झांकता': 'NA'},
#              'गूँजते': {'गूँजता': 'NA'},
#              'गान': {'गिन': 'NA', 'गात': 'NA'},
#              'गाते': {'गाने': 'NA', 'गाती': 'NA', 'गाता': 'NA'},
#              'सजाते': {'सजाता': 'NA', 'सजाने': 'NA'},
#              'खेलता': {'खेलती': 'NA', 'खेलते': 'NA', 'खेलना': 'NA'},
#              'लुटाता': {'लुटाना': 'NA'},
#              'तेज': {'तीज': 'NA', 'ताज': 'NA'},
#              'पूरा': {'पूरी': 'NA', 'पूरे': 'NA', 'पूरि': 'NA'},
#              'करता': {'करना': 'NA', 'करती': 'NA', 'करते': 'NA'},
#              'अपना': {'अपनी': 'NA', 'अपनो': 'NA', 'अपने': 'NA'},
#              'देने': {'देते': 'NA',
#               'देनी': 'NA',
#               'दीने': 'NA',
#               'दाने': 'NA',
#               'देना': 'NA'},
#              'पहुँची': {'पहुँचा': 'NA', 'पहुँचे': 'NA'},
#              'पहने': {'पहनी': 'NA'},
#              'तारे': {'तारा': 'NA',
#               'तीरे': 'NA',
#               'तेरे': 'NA',
#               'तोरे': 'NA',
#               'तारी': 'NA'},
#              'करती': {'करनी': 'NA', 'करते': 'NA', 'करता': 'NA'},
#              'देती': {'देते': 'NA', 'देनी': 'NA', 'देता': 'NA'},
#              'थके': {'थका': 'NA'},
#              'फैली': {'फैले': 'NA', 'फैला': 'NA'},
#              'तल': {'नल': 'NA'},
#              'बताने': {'बनाने': 'NA', 'बताना': 'NA', 'बताते': 'NA'},
#              'देतीं': {'देनीं': 'NA'},
#              'बानी': {'बाने': 'NA', 'बाती': 'NA', 'बिनी': 'NA', 'बाना': 'NA'},
#              'यात्रा': {'यात्री': 'NA'},
#              'जीवन': {'जीवत': 'NA', 'जेवन': 'NA'},
#              'जीने': {'जीना': 'NA', 'जाने': 'NA', 'जेने': 'NA', 'जीते': 'NA'},
#              'घाटी': {'घाटा': 'NA', 'घाटे': 'NA'},
#              'बनी': {'बती': 'NA', 'बना': 'NA', 'बने': 'NA'},
#              'छूती': {'छूते': 'NA', 'छूता': 'NA'},
#              'गया': {'गये': 'NA', 'गयी': 'NA', 'गयो': 'NA'},
#              'पड़ा': {'पड़े': 'NA', 'पड़ो': 'NA', 'पड़ी': 'NA', 'पड़ि': 'NA'},
#              'राख': {'रेख': 'NA'},
#              'झड़ती': {'झड़ते': 'NA'},
#              'इसे': {'इसा': 'NA', 'इसी': 'NA'},
#              'कहना': {'कहता': 'NA', 'कहनी': 'NA', 'कहने': 'NA'},
#              'होगा': {'होगी': 'NA'},
#              'इसके': {'इसका': 'NA', 'इसकी': 'NA'},
#              'बाद': {'बेद': 'NA'},
#              'मीठी': {'मीठे': 'NA', 'मीठा': 'NA'},
#              'कहा': {'कही': 'NA', 'कहे': 'NA', 'कहि': 'NA', 'कहो': 'NA'},
#              'लगा': {'लगि': 'NA', 'लगे': 'NA', 'लगी': 'NA'},
#              'सोचने': {'सोचना': 'NA', 'सोचते': 'NA'},
#              'थोड़ा': {'थोड़ी': 'NA', 'थोड़े': 'NA'},
#              'तुम्हारी': {'तुम्हारा': 'NA', 'तुम्हारे': 'NA'},
#              'आएगा': {'आएगी': 'NA'},
#              'कान्हा': {'कान्ही': 'NA',
#               'कान्हे': 'NA',
#               'कान्हि': 'NA',
#               'कीन्हा': 'NA'},
#              'रहते': {'रहता': 'NA', 'रहती': 'NA', 'रहने': 'NA'},
#              'बीस': {'बेस': 'NA', 'बास': 'NA'},
#              'साल': {'सील': 'NA', 'सेल': 'NA'},
#              'बने': {'बना': 'NA', 'बनी': 'NA'},
#              'होता': {'होति': 'NA', 'होती': 'NA', 'होना': 'NA', 'होते': 'NA'},
#              'मिलना': {'मिलने': 'NA', 'मिलता': 'NA'},
#              'हाल': {'होल': 'NA', 'हिल': 'NA'},
#              'मिला': {'मिलो': 'NA', 'मिले': 'NA', 'मिली': 'NA', 'मिलि': 'NA'},
#              'पुरे': {'पुरी': 'NA', 'पुरा': 'NA'},
#              'तीस': {'तास': 'NA'},
#              'दूसरे': {'दूसरी': 'NA', 'दूसरा': 'NA'},
#              'खोजते': {'खोजने': 'NA', 'खोजता': 'NA'},
#              'पुराने': {'पुराना': 'NA', 'पुरानी': 'NA'},
#              'चेहरे': {'चेहरा': 'NA'},
#              'चुके': {'चुकी': 'NA', 'चुका': 'NA'},
#              'छाप': {'छिप': 'NA'},
#              'बारे': {'बारी': 'NA', 'बोरे': 'NA', 'बारा': 'NA'},
#              'सोचते': {'सोचता': 'NA', 'सोचने': 'NA', 'सोचती': 'NA'},
#              'हमीं': {'हमें': 'NA'},
#              'बुरे': {'बुरा': 'NA', 'बुरी': 'NA'},
#              'फंसे': {'फंसा': 'NA'},
#              'कितने': {'कितना': 'NA', 'कितनी': 'NA'},
#              'मज़े': {'मज़ा': 'NA'},
#              'भरते': {'भरने': 'NA', 'भरती': 'NA', 'भरता': 'NA'},
#              'हमने': {'हमनी': 'NA'},
#              'ताश': {'नाश': 'NA'},
#              'पत्ते': {'पत्ती': 'NA', 'पत्ता': 'NA'},
#              'फेंटे': {'फेंटा': 'NA'},
#              'थे': {'था': 'NA', 'थी': 'NA'},
#              'बदले': {'बदली': 'NA', 'बदला': 'NA'},
#              'अच्छे': {'अच्छा': 'NA', 'अच्छी': 'NA'},
#              'आती': {'आते': 'NA', 'आनी': 'NA', 'आता': 'NA'},
#              'पुरानी': {'पुराने': 'NA', 'पुराना': 'NA'},
#              'उनके': {'उनकी': 'NA', 'उनका': 'NA'},
#              'ढूँढ़ा': {'ढूँढ़े': 'NA'},
#              'बताया': {'बनाया': 'NA', 'बतिया': 'NA', 'बताये': 'NA'},
#              'ठण्डा': {'ठण्डी': 'NA'},
#              'बतियाने': {'बतियाते': 'NA'},
#              'इतनी': {'इतने': 'NA', 'इतना': 'NA'},
#              'बारी': {'बारे': 'NA', 'बेरी': 'NA', 'बारा': 'NA'},
#              'लगते': {'लगती': 'NA', 'लगने': 'NA', 'लगता': 'NA'},
#              'नये': {'नयी': 'NA', 'नया': 'NA'},
#              'ज़माने': {'ज़माना': 'NA'},
#              'पड़े': {'पड़ा': 'NA', 'पड़ी': 'NA'},
#              'मिलते': {'मिलता': 'NA', 'मिलने': 'NA', 'मिलती': 'NA'},
#              'काम': {'केम': 'NA'},
#              'आया': {'आयो': 'NA', 'आयी': 'NA', 'आये': 'NA'},
#              'कैसी': {'कैसे': 'NA', 'कैसा': 'NA'},
#              'बूढ़े': {'बूढ़ी': 'NA', 'बूढ़ा': 'NA'},
#              'गोली': {'गोले': 'NA', 'गोला': 'NA'},
#              'मरे': {'मरी': 'NA', 'मरा': 'NA'},
#              'लड़के': {'लड़की': 'NA', 'लड़का': 'NA'},
#              'बूढ़ी': {'बूढ़ा': 'NA', 'बूढ़े': 'NA'},
#              'तेल': {'ताल': 'NA'},
#              'पिला': {'पिली': 'NA'},
#              'रखी': {'रखे': 'NA', 'रखा': 'NA'},
#              'टूटता': {'टूटती': 'NA', 'टूटते': 'NA'},
#              'तीरों': {'तारों': 'NA'},
#              'छूटता': {'छूटते': 'NA', 'छूटती': 'NA'},
#              'सभी': {'सभे': 'NA', 'सभा': 'NA'},
#              'फार': {'फेर': 'NA', 'फिर': 'NA', 'फोर': 'NA'},
#              'भरा': {'भरि': 'NA', 'भरो': 'NA', 'भरे': 'NA', 'भरी': 'NA'},
#              'नानी': {'तानी': 'NA', 'नाना': 'NA', 'नाती': 'NA', 'नोनी': 'NA'},
#              'जी': {'जे': 'NA', 'जा': 'NA'},
#              'राजा': {'राजी': 'NA', 'राजो': 'NA', 'राजे': 'NA', 'रोजा': 'NA'},
#              'रानी': {'राती': 'NA', 'राना': 'NA'},
#              'कहते': {'कहता': 'NA', 'कहती': 'NA', 'कहने': 'NA'},
#              'धड़कने': {'धड़कते': 'NA'},
#              'सुनते': {'सुनने': 'NA', 'सुनती': 'NA', 'सुनता': 'NA'},
#              'जाता': {'जाती': 'NA',
#               'जाति': 'NA',
#               'जाते': 'NA',
#               'जेता': 'NA',
#               'जीता': 'NA',
#               'जातो': 'NA',
#               'जाना': 'NA'},
#              'कानों': {'कोनों': 'NA'},
#              'घुसती': {'घुसते': 'NA'},
#              'उजाले': {'उजाली': 'NA', 'उजाला': 'NA'},
#              'छिपे': {'छिपी': 'NA', 'छिपा': 'NA'},
#              'अन्धेरे': {'अन्धेरी': 'NA'},
#              'नंगा': {'नंगी': 'NA', 'नंगे': 'NA'},
#              'जगा': {'जगि': 'NA', 'जगे': 'NA', 'जगी': 'NA'},
#              'दें': {'दीं': 'NA'},
#              'उनकी': {'उनका': 'NA', 'उनके': 'NA'},
#              'गिरा': {'गिरे': 'NA', 'गिरि': 'NA', 'गिरी': 'NA'},
#              'हवा': {'हवे': 'NA'},
#              'गुज़रे': {'गुज़रा': 'NA'},
#              'इतना': {'इतनी': 'NA', 'इतने': 'NA'},
#              'सटा': {'सटे': 'NA'},
#              'सजा': {'सजी': 'NA', 'सजे': 'NA', 'सजि': 'NA'},
#              'सदा': {'सदी': 'NA'},
#              'रहने': {'रहना': 'NA', 'रहनी': 'NA', 'रहते': 'NA'},
#              'लुटा': {'लुटे': 'NA', 'लुटि': 'NA', 'लुटी': 'NA'},
#              'तुम्हारे': {'तुम्हारा': 'NA', 'तुम्हारी': 'NA'},
#              'मिटा': {'मिटि': 'NA', 'मिटे': 'NA', 'मिटी': 'NA'},
#              'जिया': {'जिये': 'NA'},
#              'किया': {'कियो': 'NA', 'किये': 'NA'},
#              'जैसे': {'जैसा': 'NA', 'जैसी': 'NA'},
#              'जाल': {'जेल': 'NA', 'जोल': 'NA'},
#              'फँसे': {'फँसा': 'NA', 'फँसी': 'NA'},
#              'बँधे': {'बँधा': 'NA', 'बँधी': 'NA'},
#              'सींची': {'सींचा': 'NA', 'सींचे': 'NA'},
#              'बिछे': {'बिछा': 'NA', 'बिछी': 'NA'},
#              'चलते': {'चलता': 'NA', 'चलती': 'NA', 'चलने': 'NA'},
#              'ढलते': {'ढलता': 'NA', 'ढलती': 'NA'},
#              'जान': {'जीन': 'NA', 'जिन': 'NA', 'जात': 'NA', 'जोन': 'NA'},
#              'पाए': {'पीए': 'NA'},
#              'मीत': {'मीन': 'NA', 'मात': 'NA'},
#              'छलते': {'छलता': 'NA'},
#              'छलनी': {'छलना': 'NA'},
#              'अनजाना': {'अनजाने': 'NA', 'अनजानी': 'NA'},
#              'बाट': {'बीट': 'NA'},
#              'खिला': {'खिलि': 'NA', 'खिली': 'NA', 'खिले': 'NA'},
#              'सा': {'सो': 'NA', 'से': 'NA', 'सी': 'NA'},
#              'सीने': {'सीना': 'NA'},
#              'ताप': {'तोप': 'NA', 'नाप': 'NA'},
#              'हरा': {'हरे': 'NA', 'हरो': 'NA', 'हरि': 'NA', 'हरी': 'NA'},
#              'सारे': {'सारी': 'NA',
#               'सिरे': 'NA',
#               'सीरे': 'NA',
#               'सारा': 'NA',
#               'सोरे': 'NA'},
#              'पी': {'पा': 'NA', 'पे': 'NA'},
#              'नेह': {'नाह': 'NA', 'तेह': 'NA'},
#              'बची': {'बचा': 'NA', 'बचे': 'NA'},
#              'अगले': {'अगला': 'NA', 'अगली': 'NA'},
#              'तेरा': {'तारा': 'NA',
#               'तेरो': 'NA',
#               'तीरा': 'NA',
#               'तेरे': 'NA',
#               'तेरी': 'NA'},
#              'माथा': {'मोथा': 'NA', 'माथे': 'NA'},
#              'मेरी': {'मेरे': 'NA', 'मेरा': 'NA', 'मारी': 'NA'},
#              'जाएँगे': {'जाएँगी': 'NA'},
#              'तुम्हें': {'तुम्हीं': 'NA'},
#              'तुमने': {'तुमते': 'NA'},
#              'रक्खे': {'रक्खा': 'NA', 'रक्खी': 'NA'},
#              'हीन': {'हीत': 'NA', 'हान': 'NA'},
#              'भेजे': {'भेजा': 'NA', 'भेजी': 'NA'},
#              'बोले': {'बोला': 'NA', 'बोली': 'NA'},
#              'अनजाने': {'अनजानी': 'NA', 'अनजाना': 'NA'},
#              'मांगते': {'मांगती': 'NA'},
#              'जगाती': {'जगाते': 'NA'},
#              'मुस्कुराती': {'मुस्कुराता': 'NA'},
#              'महकती': {'महकते': 'NA'},
#              'जलाती': {'जलाते': 'NA'},
#              'रात': {'रीत': 'NA', 'रेत': 'NA', 'रान': 'NA'},
#              'बहाया': {'बहिया': 'NA', 'बहायी': 'NA'},
#              'वहीं': {'वहां': 'NA'},
#              'डूबते': {'डूबता': 'NA', 'डूबने': 'NA'},
#              'निकलते': {'निकलती': 'NA', 'निकलने': 'NA', 'निकलता': 'NA'},
#              'सताती': {'सताता': 'NA'},
#              'रहीं': {'रहें': 'NA'},
#              'जतन': {'जनन': 'NA'},
#              'तिनके': {'तिनका': 'NA'},
#              'प्रीत': {'प्रेत': 'NA', 'प्रात': 'NA'},
#              'चढ़ती': {'चढ़ते': 'NA', 'चढ़ता': 'NA', 'चढ़नी': 'NA'},
#              'उतरती': {'उतरता': 'NA', 'उतरते': 'NA'},
#              'हार': {'हेर': 'NA', 'हीर': 'NA'},
#              'अंधे': {'अंधी': 'NA', 'अंधा': 'NA'},
#              'गुज़रती': {'गुज़रता': 'NA'},
#              'सुलगती': {'सुलगते': 'NA'},
#              'जलन': {'जलत': 'NA'},
#              'भूलें': {'भूलीं': 'NA'},
#              'किसके': {'किसका': 'NA', 'किसकी': 'NA'},
#              'वादा': {'वादे': 'NA', 'विदा': 'NA', 'वादी': 'NA'},
#              'दबाये': {'दबाया': 'NA'},
#              'मेहन': {'मेहत': 'NA'},
#              'चलन': {'चलत': 'NA'},
#              'आएगी': {'आएगा': 'NA'},
#              'साया': {'साये': 'NA', 'सिया': 'NA', 'सोया': 'NA'},
#              'चाहते': {'चाहती': 'NA', 'चाहता': 'NA'},
#              'जितनी': {'जितना': 'NA', 'जितने': 'NA'},
#              'रुत': {'रुन': 'NA'},
#              'उदासी': {'उदासा': 'NA', 'उदासे': 'NA'},
#              'नशे': {'नशा': 'NA'},
#              'भेजा': {'भेजे': 'NA', 'भेजो': 'NA', 'भेजि': 'NA', 'भेजी': 'NA'},
#              'सोचता': {'सोचना': 'NA', 'सोचते': 'NA', 'सोचती': 'NA'},
#              'जाते': {'जाती': 'NA',
#               'जेते': 'NA',
#               'जाता': 'NA',
#               'जीते': 'NA',
#               'जोते': 'NA',
#               'जाने': 'NA'},
#              'सूखी': {'सूखे': 'NA', 'सूखा': 'NA'},
#              'गहरे': {'गहरा': 'NA', 'गहरी': 'NA'},
#              'पड़ता': {'पड़ते': 'NA', 'पड़ती': 'NA'},
#              'हरे': {'हरा': 'NA', 'हरी': 'NA'},
#              'जलना': {'जलने': 'NA', 'जलता': 'NA'},
#              'टूटना': {'टूटने': 'NA', 'टूटता': 'NA'},
#              'नीचे': {'नीचा': 'NA', 'नाचे': 'NA'},
#              'इन': {'इत': 'NA'},
#              'टूटती': {'टूटता': 'NA', 'टूटते': 'NA'},
#              'पहचानती': {'पहचानता': 'NA', 'पहचानते': 'NA'},
#              'बीच': {'बेच': 'NA'},
#              'उगना': {'उगता': 'NA'},
#              'बुरा': {'बुरे': 'NA', 'बुरी': 'NA'},
#              'धीमा': {'धामा': 'NA', 'धीमी': 'NA'},
#              'यहां': {'यहीं': 'NA'},
#              'धीरे': {'धारे': 'NA'},
#              'मरते': {'मरती': 'NA', 'मरने': 'NA', 'मरता': 'NA'},
#              'देखा': {'देखो': 'NA', 'देखे': 'NA', 'देखी': 'NA', 'देखि': 'NA'},
#              'मरना': {'मरने': 'NA', 'मरता': 'NA'},
#              'तुम्हारा': {'तुम्हारो': 'NA',
#               'तुम्हारे': 'NA',
#               'तुम्हारी': 'NA'},
#              'आना': {'आनी': 'NA', 'आने': 'NA', 'आता': 'NA', 'आनि': 'NA'},
#              'निशानी': {'निशाना': 'NA'},
#              'लड़की': {'लड़के': 'NA', 'लड़का': 'NA'},
#              'इतने': {'इतनी': 'NA', 'इतना': 'NA'},
#              'करीब': {'करेब': 'NA'},
#              'सोचती': {'सोचता': 'NA', 'सोचते': 'NA'},
#              'रास्ता': {'रास्ते': 'NA', 'रिस्ता': 'NA'},
#              'देखने': {'देखनी': 'NA', 'देखते': 'NA', 'देखना': 'NA'},
#              'देखती': {'देखनी': 'NA', 'देखते': 'NA', 'देखता': 'NA'},
#              'बन': {'बत': 'NA'},
#              'चुका': {'चुके': 'NA', 'चुकी': 'NA'},
#              'करने': {'करना': 'NA', 'करनी': 'NA', 'करते': 'NA'},
#              'लगी': {'लगा': 'NA', 'लगे': 'NA'},
#              'उसकी': {'उसके': 'NA', 'उसका': 'NA'},
#              'समझते': {'समझने': 'NA', 'समझती': 'NA'},
#              'लगानी': {'लगाने': 'NA', 'लगाना': 'NA', 'लगाती': 'NA'},
#              'सपना': {'सपने': 'NA', 'सपनो': 'NA'},
#              'आते': {'आने': 'NA', 'आती': 'NA', 'आता': 'NA'},
#              'रचते': {'रचती': 'NA', 'रचने': 'NA', 'रचता': 'NA'},
#              'रखते': {'रखने': 'NA', 'रखती': 'NA', 'रखता': 'NA'},
#              'जिसका': {'जिसके': 'NA', 'जिसको': 'NA', 'जिसकी': 'NA'},
#              'जाये': {'जाया': 'NA', 'जायी': 'NA', 'जीये': 'NA', 'जिये': 'NA'},
#              'ऐसा': {'ऐसो': 'NA', 'ऐसे': 'NA', 'ऐसी': 'NA'},
#              'किसे': {'किसी': 'NA'},
#              'बढता': {'बढती': 'NA'},
#              'लिये': {'लिया': 'NA'},
#              'झेलती': {'झेलते': 'NA'},
#              'ताने': {'तानी': 'NA',
#               'तेने': 'NA',
#               'तीने': 'NA',
#               'ताना': 'NA',
#               'ताते': 'NA'},
#              'उठती': {'उठता': 'NA', 'उठते': 'NA'},
#              'बच्चा': {'बच्चे': 'NA', 'बच्ची': 'NA', 'बच्चो': 'NA'},
#              'तरा': {'तरी': 'NA', 'नरा': 'NA', 'तरे': 'NA', 'तरि': 'NA'},
#              'तीसरे': {'तीसरा': 'NA'},
#              'रखती': {'रखते': 'NA', 'रखता': 'NA'},
#              'पूरी': {'पूरा': 'NA', 'पूरे': 'NA'},
#              'पीछे': {'पाछे': 'NA', 'पीछा': 'NA'},
#              'लिपटे': {'लिपटी': 'NA', 'लिपटा': 'NA'},
#              'चेतना': {'चेतनि': 'NA'},
#              'दिये': {'दिया': 'NA'},
#              'हुयी': {'हुये': 'NA'},
#              'फूले': {'फूली': 'NA', 'फूला': 'NA'},
#              'पेट': {'पाट': 'NA', 'पीट': 'NA'},
#              'किये': {'किया': 'NA'},
#              'धागे': {'धागा': 'NA'},
#              'बुनती': {'बुनता': 'NA'},
#              'आंखे': {'आंखी': 'NA'},
#              'बढ़ाती': {'बढ़ाते': 'NA'},
#              'जायेगी': {'जायेगा': 'NA', 'जायेगे': 'NA'},
#              'बेटी': {'बेटा': 'NA', 'बाटी': 'NA', 'बेटे': 'NA'},
#              'रेत': {'रीत': 'NA', 'रात': 'NA'},
#              'चारों': {'चोरों': 'NA'},
#              'लेती': {'लाती': 'NA', 'लेता': 'NA', 'लेते': 'NA', 'लेनी': 'NA'},
#              'हे': {'हा': 'NA', 'ही': 'NA'},
#              'जहां': {'जहें': 'NA'},
#              'खेल': {'खील': 'NA', 'खाल': 'NA'},
#              'पसीने': {'पसीना': 'NA'},
#              'गिरती': {'गिरता': 'NA', 'गिरते': 'NA'},
#              'खुला': {'खुली': 'NA', 'खुलो': 'NA', 'खुलि': 'NA', 'खुले': 'NA'},
#              'रखा': {'रखे': 'NA', 'रखी': 'NA'},
#              'होने': {'होनी': 'NA', 'होना': 'NA', 'होते': 'NA'},
#              'खेलना': {'खेलने': 'NA'},
#              'लेटी': {'लेटे': 'NA'},
#              'थाप': {'थोप': 'NA'},
#              'तले': {'तली': 'NA'},
#              'देह': {'दाह': 'NA', 'दीह': 'NA'},
#              'थोड़ी': {'थोड़े': 'NA', 'थोड़ा': 'NA'},
#              'नाते': {'नाती': 'NA', 'नाता': 'NA', 'ताते': 'NA', 'निते': 'NA'},
#              'नन्हें': {'नन्हीं': 'NA'},
#              'काया': {'कीया': 'NA', 'किया': 'NA'},
#              'छाया': {'छिया': 'NA', 'छाये': 'NA'},
#              'चाहता': {'चाहते': 'NA', 'चाहती': 'NA', 'चाहना': 'NA'},
#              'सके': {'सकी': 'NA', 'सका': 'NA'},
#              'कुहरा': {'कुहरे': 'NA'},
#              'कैसा': {'कैसो': 'NA', 'कैसी': 'NA', 'कैसे': 'NA'},
#              'झुकाना': {'झुकेना': 'NA'},
#              'सोना': {'सोने': 'NA', 'सोता': 'NA'},
#              'लोहा': {'लोही': 'NA', 'लोहे': 'NA', 'लोहो': 'NA'},
#              'करना': {'करनी': 'NA', 'करता': 'NA', 'करने': 'NA'},
#              'बोला': {'बोले': 'NA', 'बोलो': 'NA', 'बोलि': 'NA', 'बोली': 'NA'},
#              'करें': {'करीं': 'NA'},
#              'माँ': {'मेँ': 'NA'},
#              'उड़न': {'उड़त': 'NA'},
#              'खटोला': {'खटोली': 'NA'},
#              'प्यारे': {'प्यारा': 'NA', 'प्यारी': 'NA'},
#              'इशारे': {'इशारा': 'NA'},
#              'भेज': {'भीज': 'NA'},
#              'देते': {'देती': 'NA', 'देने': 'NA', 'देता': 'NA'},
#              'होगी': {'होगा': 'NA'},
#              'बस्ती': {'बस्ते': 'NA', 'बस्ता': 'NA'},
#              'पाऊँगा': {'पाऊँगी': 'NA'},
#              'पूछना': {'पूछने': 'NA', 'पूछनी': 'NA', 'पूछता': 'NA'},
#              'लेते': {'लेने': 'NA', 'लेता': 'NA', 'लाते': 'NA', 'लेती': 'NA'},
#              'हिस्से': {'हिस्सा': 'NA'},
#              'बड़ा': {'बड़ो': 'NA', 'बड़ी': 'NA', 'बड़ि': 'NA', 'बड़े': 'NA'},
#              'उन': {'उत': 'NA'},
#              'दी': {'दे': 'NA', 'दा': 'NA'},
#              'रतजगे': {'रतजगा': 'NA'},
#              'उभरता': {'उभरती': 'NA', 'उभरते': 'NA'},
#              'छाती': {'छाते': 'NA', 'छानी': 'NA', 'छाता': 'NA'},
#              'बीता': {'बीना': 'NA',
#               'बेता': 'NA',
#               'बीती': 'NA',
#               'बीति': 'NA',
#               'बीते': 'NA'},
#              'चलें': {'चलीं': 'NA'},
#              'सुधा': {'सुधी': 'NA', 'सुधि': 'NA'},
#              'धुली': {'धुले': 'NA'},
#              'अकेली': {'अकेला': 'NA', 'अकेले': 'NA'},
#              'मिली': {'मिले': 'NA', 'मिला': 'NA'},
#              'गीली': {'गाली': 'NA', 'गेली': 'NA', 'गीले': 'NA'},
#              'जीत': {'जीन': 'NA', 'जेत': 'NA', 'जात': 'NA'},
#              'चखा': {'चखि': 'NA'},
#              'देखे': {'देखी': 'NA', 'देखा': 'NA'},
#              'पल्ले': {'पल्ला': 'NA'},
#              'पहले': {'पहला': 'NA', 'पहली': 'NA'},
#              'गीता': {'गाता': 'NA', 'गीति': 'NA'},
#              'उडते': {'उडता': 'NA'},
#              'मैली': {'मैले': 'NA', 'मैला': 'NA'},
#              'धरती': {'धरनी': 'NA'},
#              'नाक': {'ताक': 'NA',
#               'निक': 'NA',
#               'नीक': 'NA',
#               'नेक': 'NA',
#               'नोक': 'NA'},
#              'कान': {'कात': 'NA', 'किन': 'NA', 'कीन': 'NA'},
#              'गला': {'गले': 'NA', 'गली': 'NA', 'गलि': 'NA'},
#              'काटने': {'काटते': 'NA'},
#              'तलाशते': {'तलाशने': 'NA', 'तलाशती': 'NA'},
#              'मौका': {'मौके': 'NA'},
#              'घाव': {'घीव': 'NA', 'घिव': 'NA'},
#              'मजे': {'मजा': 'NA'},
#              'धी': {'धा': 'NA'},
#              'पके': {'पका': 'NA', 'पकी': 'NA'},
#              'खाते': {'खाता': 'NA',
#               'खोते': 'NA',
#               'खाती': 'NA',
#               'खाने': 'NA',
#               'खेते': 'NA'},
#              'मुर्गे': {'मुर्गी': 'NA', 'मुर्गा': 'NA'},
#              'कच्ची': {'कच्चा': 'NA', 'कच्चे': 'NA'},
#              'लगाते': {'लगाने': 'NA', 'लगाता': 'NA', 'लगाती': 'NA'},
#              'गोते': {'गोता': 'NA'},
#              'मचाते': {'मचाता': 'NA'},
#              'मनाते': {'मनाता': 'NA', 'मनाती': 'NA'},
#              'पापा': {'पापे': 'NA', 'पीपा': 'NA', 'पापी': 'NA'},
#              'नाम': {'नीम': 'NA', 'नेम': 'NA', 'ताम': 'NA'},
#              'करेगा': {'करेगी': 'NA'},
#              'बेटा': {'बीटा': 'NA', 'बेटो': 'NA', 'बेटे': 'NA', 'बेटी': 'NA'},
#              'बैठे': {'बैठा': 'NA', 'बैठी': 'NA'},
#              'सबके': {'सबकी': 'NA', 'सबका': 'NA'},
#              'मेरा': {'मारा': 'NA',
#               'मेरे': 'NA',
#               'मीरा': 'NA',
#               'मेरो': 'NA',
#               'मेरी': 'NA'},
#              'चेहरा': {'चेहरे': 'NA'},
#              'बहार': {'बहिर': 'NA'},
#              'गालों': {'गोलों': 'NA'},
#              'बन्दा': {'बन्दे': 'NA', 'बन्दी': 'NA'},
#              'उतरा': {'उतरो': 'NA', 'उतरी': 'NA', 'उतरे': 'NA', 'उतरि': 'NA'},
#              'शीशे': {'शीशी': 'NA', 'शीशा': 'NA'},
#              'ऐसे': {'ऐसा': 'NA', 'ऐसी': 'NA'},
#              'कासे': {'केसे': 'NA', 'कासी': 'NA', 'किसे': 'NA'},
#              'जुड़ी': {'जुड़ा': 'NA', 'जुड़े': 'NA'},
#              'आता': {'आते': 'NA', 'आती': 'NA', 'आना': 'NA'},
#              'घिरा': {'घिरि': 'NA', 'घिरे': 'NA'},
#              'ख़तरे': {'ख़तरा': 'NA'},
#              'मेले': {'मेला': 'NA'},
#              'बीत': {'बात': 'NA', 'बीन': 'NA'},
#              'बीतने': {'बीतते': 'NA'},
#              'जाए': {'जीए': 'NA', 'जिए': 'NA'},
#              'गये': {'गयी': 'NA', 'गया': 'NA'},
#              'फिरने': {'फिरते': 'NA'},
#              'गुनगुनाती': {'गुनगुनाता': 'NA', 'गुनगुनाते': 'NA'},
#              'कंगूरे': {'कंगूरा': 'NA'},
#              'चले': {'चला': 'NA', 'चली': 'NA'},
#              'बुलाती': {'बुलाता': 'NA', 'बुलाते': 'NA'},
#              'पूरे': {'पूरा': 'NA', 'पूरी': 'NA'},
#              'अधूरे': {'अधूरा': 'NA', 'अधूरी': 'NA'},
#              'उठी': {'उठे': 'NA', 'उठा': 'NA'},
#              'नंगी': {'नंगा': 'NA', 'नंगे': 'NA', 'तंगी': 'NA'},
#              'गिरने': {'गिरते': 'NA'},
#              'रवे': {'रवा': 'NA'},
#              'थमी': {'थमा': 'NA'},
#              'कीली': {'काली': 'NA'},
#              'शीला': {'शाला': 'NA'},
#              'खिसका': {'खिसकी': 'NA'},
#              'मुहाने': {'मुहाना': 'NA'},
#              'बुलाने': {'बुलाते': 'NA', 'बुलाना': 'NA'},
#              'भरी': {'भरा': 'NA', 'भरे': 'NA'},
#              'अंधी': {'अंधे': 'NA', 'अंधा': 'NA'},
#              'नही': {'नहा': 'NA'},
#              'मरी': {'मरा': 'NA', 'मरे': 'NA'},
#              'गुज़री': {'गुज़रा': 'NA', 'गुज़रे': 'NA'},
#              'उठाने': {'उठाना': 'NA'},
#              'मारती': {'मारते': 'NA', 'मारता': 'NA'},
#              'छींटे': {'छींटा': 'NA', 'छांटे': 'NA'},
#              'घटा': {'घटि': 'NA', 'घटे': 'NA'},
#              'पीकर': {'पाकर': 'NA'},
#              'कलियां': {'कलियों': 'NA'},
#              'हरी': {'हरे': 'NA', 'हरा': 'NA'},
#              'छिपली': {'छिपले': 'NA'},
#              'परोसी': {'परोसा': 'NA'},
#              'जा': {'जे': 'NA', 'जो': 'NA', 'जी': 'NA'},
#              'चला': {'चले': 'NA', 'चलि': 'NA', 'चलो': 'NA', 'चली': 'NA'},
#              'फांकने': {'फेंकने': 'NA'},
#              'चबाने': {'चबाते': 'NA'},
#              'निकला': {'निकलो': 'NA',
#               'निकलि': 'NA',
#               'निकली': 'NA',
#               'निकले': 'NA'},
#              'माटी': {'मेटी': 'NA', 'मिटी': 'NA', 'मोटी': 'NA', 'माटा': 'NA'},
#              'पिछला': {'पिछले': 'NA', 'पिछली': 'NA'},
#              'कजरी': {'कजरा': 'NA'},
#              'विरहा': {'विरही': 'NA', 'विरहि': 'NA'},
#              'पगला': {'पगले': 'NA', 'पगली': 'NA'},
#              'कबीरा': {'कबीरे': 'NA'},
#              'मीरा': {'मारा': 'NA', 'मेरा': 'NA'},
#              'खेत': {'खात': 'NA'},
#              'देखें': {'देखीं': 'NA'},
#              'फूली': {'फूला': 'NA', 'फूले': 'NA'},
#              'घुमड़ते': {'घुमड़ने': 'NA'},
#              'जगता': {'जगती': 'NA', 'जगते': 'NA', 'जगना': 'NA', 'जगति': 'NA'},
#              'लहराती': {'लहराते': 'NA', 'लहराता': 'NA'},
#              'वाली': {'वाला': 'NA', 'वाले': 'NA'},
#              'नाचे': {'नीचे': 'NA', 'नाची': 'NA', 'नाचा': 'NA'},
#              'माँगे': {'माँगा': 'NA', 'माँगी': 'NA'},
#              'इसका': {'इसके': 'NA', 'इसकी': 'NA', 'इसको': 'NA'},
#              'मचला': {'मचले': 'NA'},
#              'छुपाती': {'छुपाता': 'NA'},
#              'हवेली': {'हवाली': 'NA'},
#              'कैसे': {'कैसी': 'NA', 'कैसा': 'NA'},
#              'गुजरती': {'गुजरते': 'NA'},
#              'समाना': {'समानी': 'NA', 'समाता': 'NA'},
#              'भाता': {'भाते': 'NA'},
#              'सयाने': {'सयानी': 'NA', 'सयाना': 'NA'},
#              'बनाना': {'बनाने': 'NA', 'बताना': 'NA', 'बनाता': 'NA'},
#              'मे': {'मा': 'NA'},
#              'छत': {'छन': 'NA'},
#              'खड़ा': {'खड़ी': 'NA', 'खड़े': 'NA'},
#              'नींव': {'नेंव': 'NA', 'नांव': 'NA'},
#              'कितनी': {'कितना': 'NA', 'कितने': 'NA'},
#              'लकड़ी': {'लकड़ा': 'NA'},
#              'जोड़े': {'जोड़ा': 'NA', 'जोड़ी': 'NA'},
#              'टुकड़ा': {'टुकड़े': 'NA'},
#              'घड़ी': {'घड़ा': 'NA'},
#              'घंटे': {'घंटी': 'NA', 'घंटा': 'NA'},
#              'उनींदे': {'उनींदी': 'NA'},
#              'यहीं': {'यहां': 'NA'},
#              'काली': {'काले': 'NA', 'काला': 'NA', 'कोली': 'NA'},
#              'लंबी': {'लंबे': 'NA'},
#              'निकलने': {'निकलना': 'NA', 'निकलते': 'NA'},
#              'पानी': {'पाती': 'NA', 'पाने': 'NA', 'पाना': 'NA'},
#              'लंबे': {'लंबी': 'NA'},
#              'देखता': {'देखते': 'NA',
#               'दीखता': 'NA',
#               'देखना': 'NA',
#               'देखती': 'NA'},
#              'धरने': {'धरनी': 'NA', 'धरना': 'NA'},
#              'सहेजता': {'सहेजते': 'NA'},
#              'दीन': {'दीत': 'NA', 'देन': 'NA', 'दान': 'NA'},
#              'वैसे': {'वैसा': 'NA', 'वैसी': 'NA'},
#              'हौसले': {'हौसला': 'NA'},
#              'उतरने': {'उतरना': 'NA', 'उतरते': 'NA'},
#              'ताजी': {'तेजी': 'NA', 'ताजा': 'NA'},
#              'इन्हीं': {'इन्हें': 'NA'},
#              'भरता': {'भरती': 'NA', 'भरना': 'NA', 'भरते': 'NA'},
#              'संगीत': {'संगीन': 'NA'},
#              'जीता': {'जीती': 'NA',
#               'जेता': 'NA',
#               'जाता': 'NA',
#               'जीते': 'NA',
#               'जीना': 'NA',
#               'जीति': 'NA'},
#              'खुलते': {'खुलने': 'NA', 'खुलती': 'NA'},
#              'रहती': {'रहता': 'NA', 'रहनी': 'NA', 'रहते': 'NA'},
#              'झुके': {'झुका': 'NA', 'झुकी': 'NA'},
#              'नत': {'तत': 'NA'},
#              'झुका': {'झुके': 'NA', 'झुकि': 'NA', 'झुकी': 'NA'},
#              'बीते': {'बीता': 'NA', 'बाते': 'NA', 'बीती': 'NA'},
#              'पहनता': {'पहनती': 'NA'},
#              'नया': {'नये': 'NA', 'नयी': 'NA'},
#              'जागी': {'जागा': 'NA', 'जागे': 'NA', 'जोगी': 'NA'},
#              'सारी': {'सीरी': 'NA',
#               'सिरी': 'NA',
#               'सेरी': 'NA',
#               'सारा': 'NA',
#               'सोरी': 'NA',
#               'सारे': 'NA'},
#              'तू': {'नू': 'NA'},
#              'तेरे': {'तीरे': 'NA', 'तेरा': 'NA', 'तारे': 'NA', 'तेरी': 'NA'},
#              'पक्के': {'पक्की': 'NA', 'पक्का': 'NA'},
#              'सूखे': {'सूखी': 'NA', 'सूखा': 'NA'},
#              'बुलाया': {'बुलाये': 'NA'},
#              'मिलन': {'मिलत': 'NA'},
#              'पार': {'पोर': 'NA', 'पीर': 'NA'},
#              'जाँचा': {'जाँचे': 'NA'},
#              'पायल': {'पियल': 'NA'},
#              'बजाया': {'बजाये': 'NA'},
#              'तरसते': {'तरसता': 'NA', 'तरसती': 'NA'},
#              'नाव': {'ताव': 'NA', 'नेव': 'NA'},
#              'नाचता': {'नाचती': 'NA', 'नोचता': 'NA', 'नाचते': 'NA'},
#              'नवा': {'तवा': 'NA', 'नवे': 'NA'},
#              'ताला': {'नाला': 'NA', 'ताले': 'NA', 'ताली': 'NA'},
#              'नाला': {'नीला': 'NA', 'नाली': 'NA', 'नाले': 'NA', 'ताला': 'NA'},
#              'सैय्यारा': {'सैय्यारे': 'NA'},
#              'दसत': {'दसन': 'NA'},
#              'गाह': {'गेह': 'NA'},
#              'देखना': {'देखता': 'NA', 'देखने': 'NA', 'देखनी': 'NA'},
#              'पा': {'पी': 'NA', 'पे': 'NA'},
#              'ज़ार': {'ज़ोर': 'NA'},
#              'बाल': {'बिल': 'NA', 'बेल': 'NA', 'बोल': 'NA'},
#              'नाल': {'ताल': 'NA', 'नील': 'NA'},
#              'मानी': {'माना': 'NA', 'मोनी': 'NA', 'माती': 'NA', 'माने': 'NA'},
#              'निशीन': {'निशान': 'NA'},
#              'राज़': {'रोज़': 'NA'},
#              'नहाने': {'नहाते': 'NA'},
#              'सूनी': {'सूने': 'NA', 'सूना': 'NA', 'सूती': 'NA'},
#              'झाँकना': {'झाँकता': 'NA'},
#              'आटा': {'आटे': 'NA'},
#              'घड़े': {'घड़ी': 'NA', 'घड़ा': 'NA'},
#              'कहने': {'कहनी': 'NA', 'कहना': 'NA', 'कहते': 'NA'},
#              'वैसी': {'वैसे': 'NA', 'वैसा': 'NA'},
#              'लीन': {'लेन': 'NA'},
#              'बचा': {'बचे': 'NA', 'बची': 'NA'},
#              'साथी': {'साथे': 'NA'},
#              'पुराना': {'पुराने': 'NA', 'पुरानी': 'NA'},
#              'प्यारी': {'प्यारा': 'NA', 'प्यारे': 'NA'},
#              'भेली': {'भाली': 'NA'},
#              'जवानी': {'जवाना': 'NA'},
#              'बुढ़ापा': {'बुढ़ापे': 'NA'},
#              'बुढ़ापे': {'बुढ़ापा': 'NA'},
#              'नाचना': {'नाचने': 'NA', 'नाचता': 'NA'},
#              'जिसे': {'जिसा': 'NA'},
#              'खा': {'खो': 'NA'},
#              'खोया': {'खोयी': 'NA'},
#              'खोती': {'खोते': 'NA', 'खोता': 'NA'},
#              'ज्ञान': {'ज्ञात': 'NA'},
#              'तोड़ते': {'तोड़ती': 'NA'},
#              'कटते': {'कटने': 'NA', 'कटता': 'NA'},
#              'बढ़ते': {'बढ़ने': 'NA', 'बढ़ती': 'NA', 'बढ़ता': 'NA'}})

# %%
gold_lexicon_mar = obj_eval.read_files("../evaluation_languages_home/eval_data/lexicons/hindi-urdu_source/hindi-urdu_marathi.json")

# %%
target_num = [len(tar) for key, tar in gold_lexicon_mar.items()]

# %%
sum(target_num)/len(target_num)
# Out:
# 1.2028985507246377

# %%
max(target_num)
# Out:
# 3
