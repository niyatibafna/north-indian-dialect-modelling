# %%
# Latex tables

# %%
import texttable as tt
import latextable as lt
import json
import pandas as pd

# %%
with open("../stats/stats_outputs/corpus_counts.json", "r") as f:
    corpus_counts = json.load(f)

# %%
df = pd.DataFrame(corpus_counts)
# df = df.values.tolist()
df
# t1 = tt.Texttable()
# t1.add_rows(df)
# t1.draw()
# print(lt.draw_latex(t1))
# Out:
#               folksongs  poetry  folksongs #tokens  poetry #tokens  \
# rajasthani           67    1790               7404          180320
# gujarati             14     624               1795           73363
# himachali             3       0                466               0
# hindi-urdu            1   54408                100         7127897
# magahi              340     376              37587           47167
# awadhi               47    1333               4942          495137
# punjabi             754       0              69595               0
# koraku              177       0              15509               0
# baiga                35       0              13848               0
# nimaadi             157       0              14056               0
# khadi_boli           42       0               4507               0
# bhojpuri            131    1275              20350          177289
# garwali             128     449              33380           59288
# ...

# %%
print(df.to_latex(caption = "Showing crawled corpus counts for all collected languages.", label = "tab:corpus_counts"))
# Out:
# \begin{table}
# \centering
# \caption{Showing crawled corpus counts for all collected languages.}
# \label{tab:corpus_counts}
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  folksongs &  poetry &  folksongs \#tokens &  poetry \#tokens &  total pieces &  total \#tokens \\
# \midrule
# rajasthani   &         67 &    1790 &               7404 &          180320 &          1857 &         187724 \\
# gujarati     &         14 &     624 &               1795 &           73363 &           638 &          75158 \\
# himachali    &          3 &       0 &                466 &               0 &             3 &            466 \\
# hindi-urdu   &          1 &   54408 &                100 &         7127897 &         54409 &        7127997 \\
# magahi       &        340 &     376 &              37587 &           47167 &           716 &          84754 \\
# awadhi       &         47 &    1333 &               4942 &          495137 &          1380 &         500079 \\
# ...
